# %%
import torch

# Check PyTorch version
print(f"PyTorch Version: {torch.__version__}")

# Verify if the Colab GPU is available in VS Code
gpu_available = torch.cuda.is_available()
print(f"GPU Available: {gpu_available}")

if gpu_available:
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
else:
    print("GPU Not Available")
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:b183c41d-2d11-473c-93a2-8bb90ba1281d
